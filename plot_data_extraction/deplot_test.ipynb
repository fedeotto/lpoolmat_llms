# %%
import pandas as pd
import fitz
import os
import numpy as np
from PIL import Image
from transformers import AutoProcessor, Pix2StructForConditionalGeneration

# %%
model     = Pix2StructForConditionalGeneration.from_pretrained("google/deplot")
processor = AutoProcessor.from_pretrained("google/deplot")

# %%
image       = Image.open('example2.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=707x732>

# %%
inputs      = processor(images=image, text="Generate underlying data table of the figure below:", return_tensors="pt")
predictions = model.generate(**inputs, max_new_tokens=512)
response    = processor.decode(predictions[0], skip_special_tokens=True)

print(response)
# Out:
# Year | Hispanic eligible voters | Hispanic voters | Hispanic voters <0x0A> 1986 | 7.5 | 2.9 | 8.1 <0x0A> 1990 | 8.1 | 2.9 | 0.0 <0x0A> 1994 | 10.3 | 3.5 | 0.0 <0x0A> 1998 | 12.4 | 4.1 | 0.0 <0x0A> 2002 | 14.5 | 4.5 | 0.0 <0x0A> 2006 | 17.3 | 5.6 | 0.0 <0x0A> 2010 | 21.3 | 6.6 | 0.0 <0x0A> 2014 | 25.1 | 6.8 | 0.0 <0x0A> 2018 | 29.1 | 29.1 | 0.0
